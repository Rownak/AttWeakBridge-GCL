# %%
import json
import sys
sys.path.append('../')
import config

# %%
# Load JSON file
data_dir = config.DATA_DIR
print("data dir: ",data_dir)
with open(data_dir+'attack.json', encoding='utf-8') as f:
    data = json.load(f)
# Out:
# data dir:  /home/afarhan/post-doc/AWEB_GCL/datasets/enterprise_attack/

# %%
data_keys = data.keys()
print(data_keys)
# Out:
# dict_keys(['type', 'id', 'spec_version', 'objects'])

# %% [markdown]
# #### data_keys contains the top level elements of this data file. It seems objects is of our interest
#
# How many objects are in the file?

# %%
print("Number of objects: ", len(data['objects']))
# Out:
# Number of objects:  21542

# %% [markdown]
# #### Objects have a **type** field. How many such type fileds are there?
# How many objects of each type?

# %%
from collections import Counter

# Get the list of objects
objects = data['objects']

# Get the 'type' of each object
types = [obj['type'] for obj in objects]

# Count the occurrences of each type
type_counts = Counter(types)

# print(type_counts)
# Get the maximum length of the type names
max_length = max(len(type) for type in type_counts.keys())

# Print the counts in two columns
for type, count in type_counts.items():
    print(f'{type.ljust(max_length)}: {count}')
# Out:
# x-mitre-collection    : 1
# attack-pattern        : 780
# campaign              : 28
# course-of-action      : 284
# identity              : 1
# intrusion-set         : 165
# malware               : 596
# marking-definition    : 1
# relationship          : 19438
# tool                  : 86
# x-mitre-data-component: 109
# x-mitre-data-source   : 38
# x-mitre-matrix        : 1
# x-mitre-tactic        : 14

# %% [markdown]
# #### The target is to create the graph using the relationship type objects

# %%
def getObjectsOfSpecificType(objects, theType='relationship'):
    objOfThisType=[]
    for i in range(0, len(objects)):
        if 'type' in objects[i]:
            if objects[i]['type']==theType:
                objOfThisType.append(objects[i])
    return objOfThisType

def idVSobjects(objects):
    idVSObjects={}
    for i in range(0, len(objects)):
        if 'id' in objects[i]:
            idVSObjects[objects[i]['id']]=objects[i]
    return idVSObjects

# %%
relationObjects = getObjectsOfSpecificType(objects, 'relationship')
idVsObj=idVSobjects(objects)

# %%
len(idVsObj)
# Out:
# 21542

# %%
relationObjects[0]
# Out:
# {'object_marking_refs': ['marking-definition--fa42a846-8d90-4e51-bc29-71d5b4802168'],
#  'id': 'relationship--00038d0e-7fc7-41c3-9055-edb4d87ea912',
#  'type': 'relationship',
#  'created': '2021-04-27T01:56:35.810Z',
#  'created_by_ref': 'identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5',
#  'external_references': [{'source_name': 'CheckPoint Volatile Cedar March 2015',
#    'url': 'https://media.kasperskycontenthub.com/wp-content/uploads/sites/43/2015/03/20082004/volatile-cedar-technical-report.pdf',
#    'description': 'Threat Intelligence and Research. (2015, March 30). VOLATILE CEDAR. Retrieved February 8, 2021.'}],
#  'modified': '2021-04-27T01:56:35.810Z',
#  'description': " [Explosive](https://attack.mitre.org/software/S0569) has collected the MAC address from the victim's machine.(Citation: CheckPoint Volatile Cedar March 2015) ",
#  'relationship_type': 'uses',
#  'source_ref': 'malware--6a21e3a4-5ffe-4581-af9a-6a54c7536f44',
#  'target_ref': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0',
#  'x_mitre_version': '1.0',
#  'x_mitre_modified_by_ref': 'identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5',
#  'spec_version': '2.1',
#  'x_mitre_attack_spec_version': '2.1.0',
#  'x_mitre_domains': ['enterprise-attack']}

# %%
from sklearn.metrics.pairwise import cosine_similarity

# construct nodes and links
nodes = []
links = []
count=0
# add all unique source and target refs as nodes
for relation in relationObjects:
    source_ref = relation['source_ref']
    target_ref = relation['target_ref']
    if(source_ref not in idVsObj.keys() or target_ref not in idVsObj.keys()):
        count+=1
        continue
    if source_ref not in nodes:
        nodes.append(source_ref)
    if target_ref not in nodes:
        nodes.append(target_ref)
    links.append({'source': source_ref, 'target': target_ref})

# write graph.json file
print("missing relationship: ", count)
for i in range (0, len(nodes)):
    nodeID=nodes[i]
    
    nodes[i]=idVsObj[nodeID]
    #print(nodes[i])


#graph = {'nodes': [{'id': node, 'group': 1} for node in nodes], 'links': links}
graph = {'nodes': nodes, 'links': links}
# Out:
# missing relationship:  2

# %%
links
# Out:
# [{'source': 'malware--6a21e3a4-5ffe-4581-af9a-6a54c7536f44',
#   'target': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0'},
#  {'source': 'course-of-action--21da4fd4-27ad-4e9c-b93d-0b9b14d02c96',
#   'target': 'attack-pattern--43c9bc06-715b-42db-972f-52d25c09a20c'},
#  {'source': 'x-mitre-data-component--a7f22107-02e5-4982-9067-6625d4a1765a',
#   'target': 'attack-pattern--18cffc21-3260-437e-80e4-4ab8bf2ba5e9'},
#  {'source': 'intrusion-set--01e28736-2ffc-455b-9880-ed4d1407ae07',
#   'target': 'attack-pattern--65f2d882-3f41-4d48-8a06-29af77ec9f90'},
#  {'source': 'malware--425771c5-48b4-4ecd-9f95-74ed3fc9da59',
#   'target': 'attack-pattern--bf176076-b789-408e-8cba-7275e81c0ada'},
#  {'source': 'malware--b7010785-699f-412f-ba49-524da6033c76',
#   'target': 'attack-pattern--132d5b37-aac5-4378-a8dc-3127b18a73dc'},
#  {'source': 'x-mitre-data-component--45fd904d-6eb0-4b50-8478-a961f09f898b',
#   'target': 'attack-pattern--144e007b-e638-431d-a894-45d90c54ab90'},
#  {'source': 'malware--a7881f21-e978-4fe4-af56-92c9416a2616',
#   'target': 'attack-pattern--ca9d3402-ada3-484d-876a-d717bd6e05f2'},
#  {'source': 'malware--8901ac23-6b50-410c-b0dd-d8174a86f9b3',
#   'target': 'attack-pattern--f3c544dc-673c-4ef3-accb-53229f1ae077'},
#  {'source': 'malware--8c050cea-86e1-4b63-bf21-7af4fa483349',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'campaign--df74f7ad-b10d-431c-9f1d-a2bc18dadefa',
#   'target': 'attack-pattern--4fe28b27-b13c-453e-a386-c2ef362a573b'},
#  {'source': 'intrusion-set--b7f627e2-0817-4cd5-8d50-e75f8aa85cc6',
#   'target': 'attack-pattern--10ffac09-e42d-4f56-ab20-db94c67d76ff'},
#  {'source': 'campaign--b03d5112-e23a-4ac8-add0-be7502d24eff',
#   'target': 'attack-pattern--c32f7008-9fea-41f7-8366-5eb9b74bd896'},
#  {'source': 'intrusion-set--dd2d9ca6-505b-4860-a604-233685b802c7',
#   'target': 'attack-pattern--635cbe30-392d-4e27-978e-66774357c762'},
#  {'source': 'malware--3553b49d-d4ae-4fb6-ab17-0adbc520c888',
#   'target': 'attack-pattern--3489cfc5-640f-4bb3-a103-9137b97de79f'},
#  {'source': 'intrusion-set--03506554-5f37-4f8f-9ce4-0e9f01a1b484',
#   'target': 'malware--b42378e0-f147-496f-992a-26a49705395b'},
#  {'source': 'malware--8ec6e3b4-b06d-4805-b6aa-af916acc2122',
#   'target': 'attack-pattern--4ab929c6-ee2d-4fb5-aab4-b14be2ed7179'},
#  {'source': 'malware--0f862b01-99da-47cc-9bdb-db4a86a95bb1',
#   'target': 'attack-pattern--9efb1ea7-c37b-4595-9640-b7680cd84279'},
#  {'source': 'malware--1492d0f8-7e14-4af3-9239-bc3fe10d3407',
#   'target': 'attack-pattern--322bad5a-1c49-4d23-ab79-76d641794afa'},
#  {'source': 'malware--7e100ca4-e639-48d9-9a9d-8ad84aa7b448',
#   'target': 'attack-pattern--df8b2a25-8bdf-4856-953c-a04372b1c161'},
#  {'source': 'course-of-action--78bb71be-92b4-46de-acd6-5f998fedf1cc',
#   'target': 'attack-pattern--67073dde-d720-45ae-83da-b12d5e73ca3b'},
#  {'source': 'malware--c46eb8e6-bf29-4696-8008-3ddb0b4ca470',
#   'target': 'attack-pattern--0d91b3c0-5e50-47c3-949a-2a796f04d144'},
#  {'source': 'intrusion-set--3753cc21-2dae-4dfb-8481-d004e74502cc',
#   'target': 'attack-pattern--ef67e13e-5598-4adc-bdb2-998225874fa9'},
#  {'source': 'course-of-action--20f6a9df-37c4-4e20-9e47-025983b1b39d',
#   'target': 'attack-pattern--8868cb5b-d575-4a60-acb2-07d37389a2fd'},
#  {'source': 'course-of-action--b5dbb4c5-b0b1-40b1-80b6-e9e84ab90067',
#   'target': 'attack-pattern--2b742742-28c3-4e1b-bab7-8350d6300fa7'},
#  {'source': 'malware--5c747acd-47f0-4c5a-b9e5-213541fc01e0',
#   'target': 'attack-pattern--005a06c6-14bf-4118-afa0-ebcd8aebb0c9'},
#  {'source': 'malware--d906e6f7-434c-44c0-b51a-ed50af8f7945',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--0b32ec39-ba61-4864-9ebe-b4b0b73caf9a',
#   'target': 'attack-pattern--d63a3fb8-9452-4e9d-a60a-54be68d5998c'},
#  {'source': 'intrusion-set--f8cb7b36-62ef-4488-8a6d-a7033e3271c1',
#   'target': 'attack-pattern--970a3432-3237-47ad-bcca-7d8cbb217736'},
#  {'source': 'x-mitre-data-component--74fa567d-bc90-425c-8a41-3c703abb221c',
#   'target': 'attack-pattern--70d81154-b187-45f9-8ec5-295d01255979'},
#  {'source': 'malware--d9f7383c-95ec-4080-bbce-121c9384457b',
#   'target': 'attack-pattern--b80d107d-fa0d-4b60-9684-b0433e8bdba0'},
#  {'source': 'malware--4efc3e00-72f2-466a-ab7c-8a7dc6603b19',
#   'target': 'attack-pattern--4bed873f-0b7d-41d4-b93a-b6905d1f90b0'},
#  {'source': 'intrusion-set--f8cb7b36-62ef-4488-8a6d-a7033e3271c1',
#   'target': 'attack-pattern--b18eae87-b469-4e14-b454-b171b416bc18'},
#  {'source': 'malware--cb741463-f0fe-42e0-8d45-bc7e8335f5ae',
#   'target': 'attack-pattern--dfd7cc1d-e1d8-4394-a198-97c4cab8aa67'},
#  {'source': 'malware--4dea7d8e-af94-4bfb-afe4-7ff54f59308b',
#   'target': 'attack-pattern--4f9ca633-15c5-463c-9724-bdcd54fde541'},
#  {'source': 'campaign--8d2bc130-89fe-466e-a4f9-6bce6129c2b8',
#   'target': 'malware--a394448a-4576-41b8-81cc-9b61abad94ab'},
#  {'source': 'malware--d69c8146-ab35-4d50-8382-6fc80e641d43',
#   'target': 'attack-pattern--7bc57495-ea59-4380-be31-a64af124ef18'},
#  {'source': 'attack-pattern--8d7bd4f5-3a89-4453-9c82-2c8894d5655e',
#   'target': 'attack-pattern--435dfb86-2697-4867-85b5-2fef496c0517'},
#  {'source': 'tool--cb69b20d-56d0-41ab-8440-4a4b251614d4',
#   'target': 'attack-pattern--f1951e8a-500e-4a26-8803-76d95c4554b4'},
#  {'source': 'intrusion-set--1c63d4ec-0a75-4daa-b1df-0d11af3d3cc1',
#   'target': 'attack-pattern--53ac20cd-aca3-406e-9aa0-9fc7fdc60a5a'},
#  {'source': 'course-of-action--2f316f6c-ae42-44fe-adf8-150989e0f6d3',
#   'target': 'attack-pattern--8f504411-cb96-4dac-a537-8d2bb7679c59'},
#  {'source': 'malware--edb24a93-1f7a-4bbf-a738-1397a14662c6',
#   'target': 'attack-pattern--f7827069-0bf2-4764-af4f-23fae0d181b7'},
#  {'source': 'malware--a7881f21-e978-4fe4-af56-92c9416a2616',
#   'target': 'attack-pattern--1365fe3b-0f50-455d-b4da-266ce31c23b0'},
#  {'source': 'x-mitre-data-component--235b7491-2d2b-4617-9a52-3c0783680f71',
#   'target': 'attack-pattern--8d7bd4f5-3a89-4453-9c82-2c8894d5655e'},
#  {'source': 'intrusion-set--dd2d9ca6-505b-4860-a604-233685b802c7',
#   'target': 'attack-pattern--e7cbc1de-1f79-48ee-abfd-da1241c65a15'},
#  {'source': 'malware--eac3d77f-2b7b-4599-ba74-948dc16633ad',
#   'target': 'attack-pattern--1996eef1-ced3-4d7f-bf94-33298cabbf72'},
#  {'source': 'malware--af2ad3b7-ab6a-4807-91fd-51bcaff9acbb',
#   'target': 'attack-pattern--1b7ba276-eedc-4951-a762-0ceea2c030ec'},
#  {'source': 'malware--ff6840c9-4c87-4d07-bbb6-9f50aa33d498',
#   'target': 'attack-pattern--3b744087-9945-4a6f-91e8-9dbceda417a4'},
#  {'source': 'course-of-action--9bb9e696-bff8-4ae1-9454-961fc7d91d5f',
#   'target': 'attack-pattern--005a06c6-14bf-4118-afa0-ebcd8aebb0c9'},
#  {'source': 'malware--a8a778f5-0035-4870-bb25-53dc05029586',
#   'target': 'attack-pattern--391d824f-0ef1-47a0-b0ee-c59a75e27670'},
#  {'source': 'course-of-action--93e7968a-9074-4eac-8ae9-9f5200ec3317',
#   'target': 'attack-pattern--57a3d31a-d04f-4663-b2da-7df8ec3f8c9d'},
#  {'source': 'x-mitre-data-component--3d20385b-24ef-40e1-9f56-f39750379077',
#   'target': 'attack-pattern--ec8fc7e2-b356-455c-8db5-2e37be158e7d'},
#  {'source': 'intrusion-set--4ca1929c-7d64-4aab-b849-badbfc0c760d',
#   'target': 'malware--5be33fef-39c0-4532-84ee-bea31e1b5324'},
#  {'source': 'intrusion-set--96e239be-ad99-49eb-b127-3007b8c1bec9',
#   'target': 'attack-pattern--dfebc3b7-d19d-450b-81c7-6dafe4184c04'},
#  {'source': 'malware--82cb34ba-02b5-432b-b2d2-07f55cbf674d',
#   'target': 'attack-pattern--03d7999c-1f4c-42cc-8373-e7690d318104'},
#  {'source': 'malware--fb4e3792-e915-4fdd-a9cd-92dfa2ace7aa',
#   'target': 'attack-pattern--df8b2a25-8bdf-4856-953c-a04372b1c161'},
#  {'source': 'malware--f9b05f33-d45d-4e4d-aafe-c208d38a0080',
#   'target': 'attack-pattern--677569f9-a8b0-459e-ab24-7f18091fa7bf'},
#  {'source': 'intrusion-set--c21dd6f1-1364-4a70-a1f7-783080ec34ee',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'malware--cc5497f7-a9e8-436f-94da-b2b4a9b9ad3c',
#   'target': 'attack-pattern--03d7999c-1f4c-42cc-8373-e7690d318104'},
#  {'source': 'course-of-action--1dcaeb21-9348-42ea-950a-f842aaf1ae1f',
#   'target': 'attack-pattern--7f0ca133-88c4-40c6-a62f-b3083a7fbc2e'},
#  {'source': 'campaign--808d6b30-df4e-4341-8248-724da4bac650',
#   'target': 'attack-pattern--1f9c2bae-b441-4f66-a8af-b65946ee72f2'},
#  {'source': 'malware--a7881f21-e978-4fe4-af56-92c9416a2616',
#   'target': 'attack-pattern--32901740-b42c-4fdd-bc02-345b5dc57082'},
#  {'source': 'intrusion-set--c93fccb1-e8e8-42cf-ae33-2ad1d183913a',
#   'target': 'tool--3ffbdc1f-d2bf-41ab-91a2-c7b857e98079'},
#  {'source': 'malware--63686509-069b-4143-99ea-4e59cad6cb2a',
#   'target': 'attack-pattern--c877e33f-1df6-40d6-b1e7-ce70f16f4979'},
#  {'source': 'malware--0715560d-4299-4e84-9e20-6e80ab57e4f2',
#   'target': 'attack-pattern--0d91b3c0-5e50-47c3-949a-2a796f04d144'},
#  {'source': 'malware--4b346d12-7f91-48d2-8f06-b26ffa0d825b',
#   'target': 'attack-pattern--df8b2a25-8bdf-4856-953c-a04372b1c161'},
#  {'source': 'course-of-action--90c218c3-fbf8-4830-98a7-e8cfb7eaa485',
#   'target': 'attack-pattern--4ffc1794-ec3b-45be-9e52-42dbcb2af2de'},
#  {'source': 'x-mitre-data-component--d5fca4e4-e47a-487b-873f-3d22f8865e96',
#   'target': 'attack-pattern--544b0346-29ad-41e1-a808-501bb4193f47'},
#  {'source': 'intrusion-set--c21dd6f1-1364-4a70-a1f7-783080ec34ee',
#   'target': 'attack-pattern--7385dfaf-6886-4229-9ecd-6fd678040830'},
#  {'source': 'intrusion-set--f8cb7b36-62ef-4488-8a6d-a7033e3271c1',
#   'target': 'malware--9020f5c7-efde-4125-a4f1-1b70f1274ddd'},
#  {'source': 'campaign--808d6b30-df4e-4341-8248-724da4bac650',
#   'target': 'attack-pattern--f232fa7a-025c-4d43-abc7-318e81a73d65'},
#  {'source': 'malware--0c52f5bc-557d-4083-bd27-66d7cdb794bb',
#   'target': 'attack-pattern--01a5a209-b94c-450b-b7f9-946497d91055'},
#  {'source': 'malware--a8a778f5-0035-4870-bb25-53dc05029586',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'intrusion-set--64b52e7d-b2c4-4a02-9372-08a463f5dc11',
#   'target': 'attack-pattern--d511a6f6-4a33-41d5-bc95-c343875d1377'},
#  {'source': 'malware--a545456a-f9a7-47ad-9ea6-8b017def38d1',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'malware--6f6f67c9-556d-4459-95c2-78d272190e52',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--b00f90b6-c75c-4bfd-b813-ca9e6c9ebf29',
#   'target': 'attack-pattern--0d91b3c0-5e50-47c3-949a-2a796f04d144'},
#  {'source': 'malware--f8fc98ac-ad6d-44db-b6e2-f0c6eb4eace4',
#   'target': 'attack-pattern--fa44a152-ac48-441e-a524-dd7b04b8adcd'},
#  {'source': 'malware--925a6c52-5cf0-4fec-99de-b0d6917d8593',
#   'target': 'attack-pattern--00f90846-cbd1-4fc5-9233-df5c2bf2a662'},
#  {'source': 'intrusion-set--7eda3dd8-b09b-4705-8090-c2ad9fb8c14d',
#   'target': 'tool--f59508a6-3615-47c3-b493-6676e1a39a87'},
#  {'source': 'malware--579607c2-d046-40df-99ab-beb479c37a2a',
#   'target': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0'},
#  {'source': 'x-mitre-data-component--a953ca55-921a-44f7-9b8d-3d40141aa17e',
#   'target': 'attack-pattern--1d24cdee-9ea2-4189-b08e-af110bf2435d'},
#  {'source': 'malware--7e6c2a9d-9dc1-4eb0-b27c-91e8076a9d77',
#   'target': 'attack-pattern--1996eef1-ced3-4d7f-bf94-33298cabbf72'},
#  {'source': 'x-mitre-data-component--ff93f688-d7a4-49cf-9c79-a14454da8428',
#   'target': 'attack-pattern--1f9c2bae-b441-4f66-a8af-b65946ee72f2'},
#  {'source': 'intrusion-set--ead23196-d7b6-4ce6-a124-4ab4b67d81bd',
#   'target': 'attack-pattern--0d91b3c0-5e50-47c3-949a-2a796f04d144'},
#  {'source': 'intrusion-set--16ade1aa-0ea1-4bb7-88cc-9079df2ae756',
#   'target': 'malware--123bd7b3-675c-4b1a-8482-c55782b20e2b'},
#  {'source': 'malware--6b62e336-176f-417b-856a-8552dd8c44e1',
#   'target': 'attack-pattern--c32f7008-9fea-41f7-8366-5eb9b74bd896'},
#  {'source': 'intrusion-set--6fe8a2a1-a1b0-4af8-953d-4babd329f8f8',
#   'target': 'attack-pattern--2b742742-28c3-4e1b-bab7-8350d6300fa7'},
#  {'source': 'malware--f8fc98ac-ad6d-44db-b6e2-f0c6eb4eace4',
#   'target': 'attack-pattern--dd43c543-bb85-4a6f-aa6e-160d90d06a49'},
#  {'source': 'x-mitre-data-component--0dcbbf4f-929c-489a-b66b-9b820d3f7f0e',
#   'target': 'attack-pattern--e5d550f3-2202-4634-85f2-4a200a1d49b3'},
#  {'source': 'malware--8c1d01ff-fdc0-4586-99bd-c248e0761af5',
#   'target': 'attack-pattern--2b742742-28c3-4e1b-bab7-8350d6300fa7'},
#  {'source': 'intrusion-set--bf668120-e9a6-4017-a014-bfc0f5232656',
#   'target': 'attack-pattern--232b7f21-adf9-4b42-b936-b9d6f7df856e'},
#  {'source': 'x-mitre-data-component--9ce98c86-8d30-4043-ba54-0784d478d0b5',
#   'target': 'attack-pattern--1608f3e1-598a-42f4-a01a-2e252e81728f'},
#  {'source': 'intrusion-set--cc613a49-9bfa-4e22-98d1-15ffbb03f034',
#   'target': 'attack-pattern--88d31120-5bc7-4ce3-a9c0-7cf147be8e54'},
#  {'source': 'malware--7acb15b6-fe2c-4319-b136-6ab36ff0b2d4',
#   'target': 'attack-pattern--57340c81-c025-4189-8fa0-fc7ede51bae4'},
#  {'source': 'malware--af2ad3b7-ab6a-4807-91fd-51bcaff9acbb',
#   'target': 'attack-pattern--0d91b3c0-5e50-47c3-949a-2a796f04d144'},
#  {'source': 'x-mitre-data-component--9bde2f9d-a695-4344-bfac-f2dce13d121e',
#   'target': 'attack-pattern--ea016b56-ae0e-47fe-967a-cc0ad51af67f'},
#  {'source': 'malware--5763217a-05b6-4edd-9bca-057e47b5e403',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'x-mitre-data-component--3d20385b-24ef-40e1-9f56-f39750379077',
#   'target': 'attack-pattern--cc89ecbd-3d33-4a41-bcca-001e702d18fd'},
#  {'source': 'x-mitre-data-component--a7f22107-02e5-4982-9067-6625d4a1765a',
#   'target': 'attack-pattern--d456de47-a16f-4e46-8980-e67478a12dcb'},
#  {'source': 'malware--d79e7a60-5de9-448e-a074-f95d2d80f8d0',
#   'target': 'attack-pattern--01a5a209-b94c-450b-b7f9-946497d91055'},
#  {'source': 'malware--06d735e7-1db1-4dbe-ab4b-acbe419f902b',
#   'target': 'attack-pattern--7bc57495-ea59-4380-be31-a64af124ef18'},
#  {'source': 'malware--67e6d66b-1b82-4699-b47a-e2efb6268d14',
#   'target': 'attack-pattern--d1fcf083-a721-4223-aedf-bf8960798d62'},
#  {'source': 'x-mitre-data-component--3d20385b-24ef-40e1-9f56-f39750379077',
#   'target': 'attack-pattern--f5d8eed6-48a9-4cdf-a3d7-d1ffa99c3d2a'},
#  {'source': 'malware--d3afa961-a80c-4043-9509-282cdf69ab21',
#   'target': 'attack-pattern--391d824f-0ef1-47a0-b0ee-c59a75e27670'},
#  {'source': 'malware--a8d3d497-2da9-4797-8e0b-ed176be08654',
#   'target': 'attack-pattern--f0589bc3-a6ae-425a-a3d5-5659bfee07f4'},
#  {'source': 'malware--8f423bd7-6ca7-4303-9e85-008c7ad5fdaa',
#   'target': 'attack-pattern--7bc57495-ea59-4380-be31-a64af124ef18'},
#  {'source': 'tool--cb69b20d-56d0-41ab-8440-4a4b251614d4',
#   'target': 'attack-pattern--e3a12395-188d-4051-9a16-ea8e14d07b88'},
#  {'source': 'course-of-action--590777b3-b475-4c7c-aaf8-f4a73b140312',
#   'target': 'attack-pattern--d456de47-a16f-4e46-8980-e67478a12dcb'},
#  {'source': 'malware--00806466-754d-44ea-ad6f-0caf59cb8556',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--0db09158-6e48-4e7c-8ce7-2b10b9c0c039',
#   'target': 'attack-pattern--1c4e5d32-1fe9-4116-9d9d-59e3925bd6a2'},
#  {'source': 'malware--6ba1d7ae-d60b-43e6-9f08-a8b787e9d9cb',
#   'target': 'attack-pattern--d63a3fb8-9452-4e9d-a60a-54be68d5998c'},
#  {'source': 'malware--8a59f456-79a0-4151-9f56-9b1a67332af2',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'intrusion-set--7a19ecb1-3c65-4de3-a230-993516aed6a6',
#   'target': 'attack-pattern--ae797531-3219-49a4-bccf-324ad7a4c7b2'},
#  {'source': 'intrusion-set--5cbe0d3b-6fb1-471f-b591-4b192915116d',
#   'target': 'malware--9e9b9415-a7df-406b-b14d-92bfe6809fbe'},
#  {'source': 'malware--91c57ed3-7c32-4c68-b388-7db00cb8dac6',
#   'target': 'attack-pattern--2959d63f-73fd-46a1-abd2-109d7dcede32'},
#  {'source': 'malware--c13d9621-aca7-436b-ab3d-3a95badb3d00',
#   'target': 'attack-pattern--32901740-b42c-4fdd-bc02-345b5dc57082'},
#  {'source': 'campaign--f9cc545e-b0ef-4b92-8884-a3a4427609f6',
#   'target': 'tool--13cd9151-83b7-410d-9f98-25d0f0d1d80d'},
#  {'source': 'intrusion-set--35d1b3be-49d4-42f1-aaa6-ef159c880bca',
#   'target': 'attack-pattern--10d51417-ee35-4589-b1ff-b6df1c334e8d'},
#  {'source': 'intrusion-set--2a7914cf-dff3-428d-ab0f-1014d1c28aeb',
#   'target': 'malware--432555de-63bf-4f2a-a3fa-f720a4561078'},
#  {'source': 'malware--cb444a16-3ea5-4a91-88c6-f329adcb8af3',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--bdb27a1d-1844-42f1-a0c0-826027ae0326',
#   'target': 'attack-pattern--03d7999c-1f4c-42cc-8373-e7690d318104'},
#  {'source': 'intrusion-set--d13c8a7f-740b-4efa-a232-de7d6bb05321',
#   'target': 'attack-pattern--b18eae87-b469-4e14-b454-b171b416bc18'},
#  {'source': 'intrusion-set--17862c7d-9e60-48a0-b48e-da4dc4c3f6b0',
#   'target': 'attack-pattern--dfd7cc1d-e1d8-4394-a198-97c4cab8aa67'},
#  {'source': 'malware--29a0bb87-1162-4c83-9834-2a98a876051b',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'x-mitre-data-component--da85d358-741a-410d-9433-20d6269a6170',
#   'target': 'attack-pattern--57340c81-c025-4189-8fa0-fc7ede51bae4'},
#  {'source': 'tool--362dc67f-4e85-4562-9dac-1b6b7f3ec4b5',
#   'target': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0'},
#  {'source': 'intrusion-set--bef4c620-0787-42a8-a96d-b7eb6e85917c',
#   'target': 'attack-pattern--edf91964-b26e-4b4a-9600-ccacd7d7df24'},
#  {'source': 'malware--198db886-47af-4f4c-bff5-11b891f85946',
#   'target': 'attack-pattern--f5946b5e-9408-485f-a7f7-b5efc88909b6'},
#  {'source': 'malware--f25aab1a-0cef-4910-a85d-bb38b32ea41a',
#   'target': 'attack-pattern--1996eef1-ced3-4d7f-bf94-33298cabbf72'},
#  {'source': 'malware--edf5aee2-9b1c-4252-8e64-25b12f14c8b3',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'intrusion-set--8b1e16f6-e7c8-4b7a-a5df-f81232c13e2f',
#   'target': 'attack-pattern--01a5a209-b94c-450b-b7f9-946497d91055'},
#  {'source': 'intrusion-set--f29b7c5e-2439-42ad-a86f-9f8984fafae3',
#   'target': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0'},
#  {'source': 'malware--6b62e336-176f-417b-856a-8552dd8c44e1',
#   'target': 'attack-pattern--8f4a33ec-8b1f-4b80-a2f6-642b2e479580'},
#  {'source': 'intrusion-set--9e729a7e-0dd6-4097-95bf-db8d64911383',
#   'target': 'attack-pattern--cba37adb-d6fb-4610-b069-dd04c0643384'},
#  {'source': 'malware--222ba512-32d9-49ac-aefd-50ce981ce2ce',
#   'target': 'attack-pattern--391d824f-0ef1-47a0-b0ee-c59a75e27670'},
#  {'source': 'tool--afc079f3-c0ea-4096-b75d-3f05338b7f60',
#   'target': 'attack-pattern--f303a39a-6255-4b89-aecc-18c4d8ca7163'},
#  {'source': 'malware--579607c2-d046-40df-99ab-beb479c37a2a',
#   'target': 'attack-pattern--53ac20cd-aca3-406e-9aa0-9fc7fdc60a5a'},
#  {'source': 'intrusion-set--6713ab67-e25b-49cc-808d-2b36d4fbc35c',
#   'target': 'attack-pattern--b4694861-542c-48ea-9eb1-10d356e7140a'},
#  {'source': 'campaign--8d2bc130-89fe-466e-a4f9-6bce6129c2b8',
#   'target': 'malware--be25c1c0-1590-4219-a3d5-6f31799d1d1b'},
#  {'source': 'malware--0f862b01-99da-47cc-9bdb-db4a86a95bb1',
#   'target': 'attack-pattern--0d91b3c0-5e50-47c3-949a-2a796f04d144'},
#  {'source': 'malware--ab3580c8-8435-4117-aace-3d9fbe46aa56',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--60d50676-459a-47dd-92e9-a827a9fe9c58',
#   'target': 'attack-pattern--ac08589e-ee59-4935-8667-d845e38fe579'},
#  {'source': 'malware--8ec6e3b4-b06d-4805-b6aa-af916acc2122',
#   'target': 'attack-pattern--01a5a209-b94c-450b-b7f9-946497d91055'},
#  {'source': 'tool--03342581-f790-4f03-ba41-e82e67392e23',
#   'target': 'attack-pattern--b6075259-dba3-44e9-87c7-e954f37ec0d5'},
#  {'source': 'malware--b350b47f-88fe-4921-8538-6d9c59bac84e',
#   'target': 'attack-pattern--391d824f-0ef1-47a0-b0ee-c59a75e27670'},
#  {'source': 'malware--56aa3c82-ed40-4b5a-84bf-7231356d9e96',
#   'target': 'attack-pattern--03d7999c-1f4c-42cc-8373-e7690d318104'},
#  {'source': 'intrusion-set--32bca8ff-d900-4877-aa65-d70baa041b74',
#   'target': 'tool--b76b2d94-60e4-4107-a903-4a3a7622fb3b'},
#  {'source': 'malware--471d0e9f-2c8a-4e4b-8f3b-f85d2407806e',
#   'target': 'attack-pattern--d63a3fb8-9452-4e9d-a60a-54be68d5998c'},
#  {'source': 'malware--9a097d18-d15f-4635-a4f1-189df7efdc40',
#   'target': 'attack-pattern--df8b2a25-8bdf-4856-953c-a04372b1c161'},
#  {'source': 'x-mitre-data-component--685f917a-e95e-4ba0-ade1-c7d354dae6e0',
#   'target': 'attack-pattern--92d7da27-2d91-488e-a00c-059dc162766d'},
#  {'source': 'intrusion-set--f9d6633a-55e6-4adc-9263-6ae080421a13',
#   'target': 'attack-pattern--09a60ea3-a8d1-4ae5-976e-5783248b72a4'},
#  {'source': 'malware--f01e2711-4b48-4192-a2e8-5f56c945ca19',
#   'target': 'attack-pattern--24bfaeba-cb0d-4525-b3dc-507c77ecec41'},
#  {'source': 'intrusion-set--4ca1929c-7d64-4aab-b849-badbfc0c760d',
#   'target': 'attack-pattern--d336b553-5da9-46ca-98a8-0b23f49fb447'},
#  {'source': 'intrusion-set--899ce53f-13a0-479b-a0e4-67d46e241542',
#   'target': 'malware--ae9d818d-95d0-41da-b045-9cabea1ca164'},
#  {'source': 'course-of-action--78bb71be-92b4-46de-acd6-5f998fedf1cc',
#   'target': 'attack-pattern--937e4772-8441-4e4a-8bf0-8d447d667e23'},
#  {'source': 'malware--2eaa5319-5e1e-4dd7-bbc4-566fced3964a',
#   'target': 'attack-pattern--b80d107d-fa0d-4b60-9684-b0433e8bdba0'},
#  {'source': 'tool--e33267fe-099f-4af2-8730-63d49f8813b2',
#   'target': 'attack-pattern--f2877f7f-9a4c-4251-879f-1224e3006bee'},
#  {'source': 'course-of-action--eb88d97c-32f1-40be-80f0-d61a4b0b4b31',
#   'target': 'attack-pattern--e5cc9e7a-e61a-46a1-b869-55fb6eab058e'},
#  {'source': 'malware--8d242fb4-9033-4f13-8a88-4b9b4bcd9a53',
#   'target': 'attack-pattern--f5d8eed6-48a9-4cdf-a3d7-d1ffa99c3d2a'},
#  {'source': 'course-of-action--eb88d97c-32f1-40be-80f0-d61a4b0b4b31',
#   'target': 'attack-pattern--2db31dcd-54da-405d-acef-b9129b816ed6'},
#  {'source': 'malware--f4d8a2d6-c684-453a-8a14-cf4a94f755c5',
#   'target': 'attack-pattern--df8b2a25-8bdf-4856-953c-a04372b1c161'},
#  {'source': 'malware--4ab44516-ad75-4e43-a280-705dc0420e2f',
#   'target': 'attack-pattern--3ccef7ae-cb5e-48f6-8302-897105fbf55c'},
#  {'source': 'malware--e2d34c63-6f5a-41f5-86a2-e2380f27f858',
#   'target': 'attack-pattern--3ccef7ae-cb5e-48f6-8302-897105fbf55c'},
#  {'source': 'course-of-action--987988f0-cf86-4680-a875-2f6456ab2448',
#   'target': 'attack-pattern--1c4e5d32-1fe9-4116-9d9d-59e3925bd6a2'},
#  {'source': 'intrusion-set--129f2f77-1ab2-4c35-bd5e-21260cee92af',
#   'target': 'malware--99fdf3b4-96ef-4ab9-b191-fc683441cad0'},
#  {'source': 'intrusion-set--381fcf73-60f6-4ab2-9991-6af3cbc35192',
#   'target': 'attack-pattern--2b5aa86b-a0df-4382-848d-30abea443327'},
#  {'source': 'campaign--4553292d-12c6-4a93-934d-12160370d4e0',
#   'target': 'attack-pattern--65013dd2-bc61-43e3-afb5-a14c4fa7437a'},
#  {'source': 'x-mitre-data-component--45977f14-1bcc-4ec4-ac14-a30fd3a11f44',
#   'target': 'attack-pattern--d4bdbdea-eaec-4071-b4f9-5105e12ea4b6'},
#  {'source': 'x-mitre-data-component--faa34cf6-cf32-4dc9-bd6a-8f7a606ff65b',
#   'target': 'attack-pattern--799ace7f-e227-4411-baa0-8868704f2a69'},
#  {'source': 'course-of-action--20f6a9df-37c4-4e20-9e47-025983b1b39d',
#   'target': 'attack-pattern--035bb001-ab69-4a0b-9f6c-2de8b09e1b9d'},
#  {'source': 'malware--99164b38-1775-40bc-b77b-a2373b14540a',
#   'target': 'attack-pattern--df8b2a25-8bdf-4856-953c-a04372b1c161'},
#  {'source': 'intrusion-set--dc6fe6ee-04c2-49be-ba3d-f38d2463c02a',
#   'target': 'attack-pattern--2e34237d-8574-43f6-aace-ae2915de8597'},
#  {'source': 'campaign--aa73efef-1418-4dbe-b43c-87a498e97234',
#   'target': 'attack-pattern--dfd7cc1d-e1d8-4394-a198-97c4cab8aa67'},
#  {'source': 'campaign--b03d5112-e23a-4ac8-add0-be7502d24eff',
#   'target': 'attack-pattern--65f2d882-3f41-4d48-8a06-29af77ec9f90'},
#  {'source': 'x-mitre-data-component--9ce98c86-8d30-4043-ba54-0784d478d0b5',
#   'target': 'attack-pattern--b4409cd8-0da9-46e1-a401-a241afd4d1cc'},
#  {'source': 'x-mitre-data-component--7f70fae7-a68d-4730-a83a-f260b9606129',
#   'target': 'attack-pattern--005a06c6-14bf-4118-afa0-ebcd8aebb0c9'},
#  {'source': 'malware--04378e79-4387-468a-a8f7-f974b8254e44',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--088f1d6e-0783-47c6-9923-9c79b2af43d4',
#   'target': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0'},
#  {'source': 'malware--8dbadf80-468c-4a62-b817-4e4d8b606887',
#   'target': 'attack-pattern--82caa33e-d11a-433a-94ea-9b5a5fbef81d'},
#  {'source': 'malware--b96680d1-5eb3-4f07-b95c-00ab904ac236',
#   'target': 'attack-pattern--9efb1ea7-c37b-4595-9640-b7680cd84279'},
#  {'source': 'course-of-action--cc2399fd-3cd3-4319-8d0a-fbd6420cdaf8',
#   'target': 'attack-pattern--ebb42bbe-62d7-47d7-a55f-3b08b61d792d'},
#  {'source': 'malware--67e6d66b-1b82-4699-b47a-e2efb6268d14',
#   'target': 'attack-pattern--7b211ac6-c815-4189-93a9-ab415deca926'},
#  {'source': 'malware--df9b350b-d4f9-4e79-a826-75cc75fbc1eb',
#   'target': 'attack-pattern--2e34237d-8574-43f6-aace-ae2915de8597'},
#  {'source': 'x-mitre-data-component--3d20385b-24ef-40e1-9f56-f39750379077',
#   'target': 'attack-pattern--045d0922-2310-4e60-b5e4-3302302cb3c5'},
#  {'source': 'intrusion-set--39d6890e-7f23-4474-b8ef-e7b0343c5fc8',
#   'target': 'malware--44c75271-0e4d-496f-ae0a-a6d883a42a65'},
#  {'source': 'malware--e401d4fe-f0c9-44f0-98e6-f93487678808',
#   'target': 'attack-pattern--2959d63f-73fd-46a1-abd2-109d7dcede32'},
#  {'source': 'intrusion-set--64b52e7d-b2c4-4a02-9372-08a463f5dc11',
#   'target': 'attack-pattern--d63a3fb8-9452-4e9d-a60a-54be68d5998c'},
#  {'source': 'malware--bbcd7a02-ef24-4171-ac94-a93540173b94',
#   'target': 'attack-pattern--1b7b1806-7746-41a1-a35d-e48dae25ddba'},
#  {'source': 'intrusion-set--2688b13e-8e71-405a-9c40-0dee94bddf87',
#   'target': 'attack-pattern--774ad5bb-2366-4c13-a8a9-65e50b292e7c'},
#  {'source': 'x-mitre-data-component--a7f22107-02e5-4982-9067-6625d4a1765a',
#   'target': 'attack-pattern--5b0ad6f8-6a16-4966-a4ef-d09ea6e2a9f5'},
#  {'source': 'malware--727afb95-3d0f-4451-b297-362a43909923',
#   'target': 'attack-pattern--b80d107d-fa0d-4b60-9684-b0433e8bdba0'},
#  {'source': 'intrusion-set--7eda3dd8-b09b-4705-8090-c2ad9fb8c14d',
#   'target': 'attack-pattern--4bc31b94-045b-4752-8920-aebaebdb6470'},
#  {'source': 'malware--5faaf81a-aa5b-4a4b-bae5-522439e068f8',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'intrusion-set--44e43fad-ffcb-4210-abcf-eaaed9735f80',
#   'target': 'attack-pattern--e3a12395-188d-4051-9a16-ea8e14d07b88'},
#  {'source': 'intrusion-set--269e8108-68c6-4f99-b911-14b2e765dec2',
#   'target': 'attack-pattern--2b742742-28c3-4e1b-bab7-8350d6300fa7'},
#  {'source': 'malware--88c621a7-aef9-4ae0-94e3-1fc87123eb24',
#   'target': 'attack-pattern--0a5231ec-41af-4a35-83d0-6bdf11f28c65'},
#  {'source': 'x-mitre-data-component--5c6de881-bc70-4070-855a-7a9631a407f7',
#   'target': 'attack-pattern--f303a39a-6255-4b89-aecc-18c4d8ca7163'},
#  {'source': 'intrusion-set--dd2d9ca6-505b-4860-a604-233685b802c7',
#   'target': 'malware--00806466-754d-44ea-ad6f-0caf59cb8556'},
#  {'source': 'malware--b8fdef82-d2cf-4948-8949-6466357b1be1',
#   'target': 'attack-pattern--d10cbd34-42e3-45c0-84d2-535a09849584'},
#  {'source': 'intrusion-set--00f67a77-86a4-4adf-be26-1a54fc713340',
#   'target': 'attack-pattern--b80d107d-fa0d-4b60-9684-b0433e8bdba0'},
#  {'source': 'malware--db1355a7-e5c9-4e2c-8da7-eccf2ae9bf5c',
#   'target': 'attack-pattern--7c0f17c9-1af6-4628-9cbd-9e45482dd605'},
#  {'source': 'malware--4b072c90-bc7a-432b-940e-016fc1c01761',
#   'target': 'attack-pattern--a782ebe2-daba-42c7-bc82-e8e9d923162d'},
#  {'source': 'intrusion-set--174279b4-399f-4ddb-966e-5efedd1dd5f2',
#   'target': 'tool--5a63f900-5e7e-4928-a746-dd4558e1df71'},
#  {'source': 'malware--c984b414-b766-44c5-814a-2fe96c913c12',
#   'target': 'attack-pattern--0d91b3c0-5e50-47c3-949a-2a796f04d144'},
#  {'source': 'tool--b1595ddd-a783-482a-90e1-8afc8d48467e',
#   'target': 'attack-pattern--cc3502b5-30cc-4473-ad48-42d51a6ef6d1'},
#  {'source': 'intrusion-set--e44e0985-bc65-4a8f-b578-211c858128e3',
#   'target': 'attack-pattern--d742a578-d70e-4d0e-96a6-02a9c30204e6'},
#  {'source': 'intrusion-set--899ce53f-13a0-479b-a0e4-67d46e241542',
#   'target': 'tool--6dbdc657-d8e0-4f2f-909b-7251b3e72c6d'},
#  {'source': 'attack-pattern--c3c8c916-2f3c-4e71-94b2-240bdfc996f0',
#   'target': 'attack-pattern--51a14c76-dd3b-440b-9c20-2bf91d25a814'},
#  {'source': 'malware--36801ffb-5c85-4c50-9121-6122e389366d',
#   'target': 'attack-pattern--3ccef7ae-cb5e-48f6-8302-897105fbf55c'},
#  {'source': 'intrusion-set--a7f57cc1-4540-4429-823f-f4e56b8473c9',
#   'target': 'attack-pattern--2e34237d-8574-43f6-aace-ae2915de8597'},
#  {'source': 'malware--979adb5a-dc30-48f0-9e3d-9a26d866928c',
#   'target': 'attack-pattern--c32f7008-9fea-41f7-8366-5eb9b74bd896'},
#  {'source': 'malware--a8a778f5-0035-4870-bb25-53dc05029586',
#   'target': 'attack-pattern--9efb1ea7-c37b-4595-9640-b7680cd84279'},
#  {'source': 'x-mitre-data-component--84572de3-9583-4c73-aabd-06ea88123dd8',
#   'target': 'attack-pattern--005a06c6-14bf-4118-afa0-ebcd8aebb0c9'},
#  {'source': 'tool--26c87906-d750-42c5-946c-d4162c73fc7b',
#   'target': 'attack-pattern--650c784b-7504-4df7-ab2c-4ea882384d1e'},
#  {'source': 'tool--6a5947f3-1a36-4653-8734-526df3e1d28d',
#   'target': 'attack-pattern--e4dc8c01-417f-458d-9ee0-bb0617c1b391'},
#  {'source': 'malware--00806466-754d-44ea-ad6f-0caf59cb8556',
#   'target': 'attack-pattern--03d7999c-1f4c-42cc-8373-e7690d318104'},
#  {'source': 'x-mitre-data-component--b9a1578e-8653-4103-be23-cb52e0b1816e',
#   'target': 'attack-pattern--bf90d72c-c00b-45e3-b3aa-68560560d4c5'},
#  {'source': 'malware--f559f945-eb8b-48b1-904c-68568deebed3',
#   'target': 'attack-pattern--005a06c6-14bf-4118-afa0-ebcd8aebb0c9'},
#  {'source': 'intrusion-set--c93fccb1-e8e8-42cf-ae33-2ad1d183913a',
#   'target': 'attack-pattern--d1fcf083-a721-4223-aedf-bf8960798d62'},
#  {'source': 'intrusion-set--247cb30b-955f-42eb-97a5-a89fef69341e',
#   'target': 'tool--afc079f3-c0ea-4096-b75d-3f05338b7f60'},
#  {'source': 'intrusion-set--93f52415-0fe4-4d3d-896c-fc9b8e88ab90',
#   'target': 'attack-pattern--3ccef7ae-cb5e-48f6-8302-897105fbf55c'},
#  {'source': 'malware--dfa03c7d-79ed-4ce2-b9d1-ddc9dbf56ad2',
#   'target': 'attack-pattern--92d7da27-2d91-488e-a00c-059dc162766d'},
#  {'source': 'malware--7e0f8b0f-716e-494d-827e-310bd6ed709e',
#   'target': 'attack-pattern--24bfaeba-cb0d-4525-b3dc-507c77ecec41'},
#  {'source': 'intrusion-set--5f3d0238-d058-44a9-8812-3dd1b6741a8c',
#   'target': 'malware--750eb92a-7fdf-451e-9592-1d42357018f1'},
#  {'source': 'x-mitre-data-component--2b3bfe19-d59a-460d-93bb-2f546adc2d2c',
#   'target': 'attack-pattern--1126cab1-c700-412f-a510-61f4937bb096'},
#  {'source': 'malware--dcac85c1-6485-4790-84f6-de5e6f6b91dd',
#   'target': 'attack-pattern--be055942-6e63-49d7-9fa1-9cb7d8a8f3f4'},
#  {'source': 'intrusion-set--c1aab4c9-4c34-4f4f-8541-d529e46a07f9',
#   'target': 'attack-pattern--970a3432-3237-47ad-bcca-7d8cbb217736'},
#  {'source': 'course-of-action--9bb9e696-bff8-4ae1-9454-961fc7d91d5f',
#   'target': 'attack-pattern--7b211ac6-c815-4189-93a9-ab415deca926'},
#  {'source': 'campaign--b03d5112-e23a-4ac8-add0-be7502d24eff',
#   'target': 'attack-pattern--09a60ea3-a8d1-4ae5-976e-5783248b72a4'},
#  {'source': 'intrusion-set--9735c036-8ebe-47e9-9c77-b0ae656dab93',
#   'target': 'attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df007ca70a'},
#  {'source': 'intrusion-set--35d1b3be-49d4-42f1-aaa6-ef159c880bca',
#   'target': 'attack-pattern--4061e78c-1284-44b4-9116-73e4ac3912f7'},
#  {'source': 'intrusion-set--0ec2f388-bf0f-4b5c-97b1-fc736d26c25f',
#   'target': 'attack-pattern--3c4a2599-71ee-4405-ba1e-0e28414b4bc5'},
#  {'source': 'malware--94d6d788-07bb-4dcc-b62f-e02626b00108',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'intrusion-set--7113eaa5-ba79-4fb3-b68a-398ee9cd698e',
#   'target': 'attack-pattern--bf1b6176-597c-4600-bfcd-ac989670f96b'},
#  {'source': 'intrusion-set--fa19de15-6169-428d-9cd6-3ca3d56075b7',
#   'target': 'tool--9a2640c2-9f43-46fe-b13f-bde881e55555'},
#  {'source': 'intrusion-set--46bb06cb-f2d9-4b37-8c92-a27e224ad90d',
#   'target': 'attack-pattern--bf1b6176-597c-4600-bfcd-ac989670f96b'},
#  {'source': 'intrusion-set--6fe8a2a1-a1b0-4af8-953d-4babd329f8f8',
#   'target': 'attack-pattern--ef67e13e-5598-4adc-bdb2-998225874fa9'},
#  {'source': 'intrusion-set--420ac20b-f2b9-42b8-aa1a-6d4b72895ca4',
#   'target': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0'},
#  {'source': 'intrusion-set--6fe8a2a1-a1b0-4af8-953d-4babd329f8f8',
#   'target': 'malware--b57f419e-8b12-49d3-886b-145383725dcd'},
#  {'source': 'malware--7724581b-06ff-4d2b-b77c-80dc8d53070b',
#   'target': 'attack-pattern--b97f1d35-4249-4486-a6b5-ee60ccf24fab'},
#  {'source': 'malware--63c2a130-8a5b-452f-ad96-07cf0af12ffe',
#   'target': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0'},
#  {'source': 'course-of-action--47e0e9fe-96ce-4f65-8bb1-8be1feacb5db',
#   'target': 'attack-pattern--e6f19759-dde3-47fc-99cc-d9f5fa4ade60'},
#  {'source': 'course-of-action--e3388c78-2a8d-47c2-8422-c1398b324462',
#   'target': 'attack-pattern--3fc01293-ef5e-41c6-86ce-61f10706b64a'},
#  {'source': 'intrusion-set--d8bc9788-4f7d-41a9-9e9d-ee1ea18a8cf7',
#   'target': 'attack-pattern--5282dd9a-d26d-4e16-88b7-7c0f4553daf4'},
#  {'source': 'attack-pattern--a009cb25-4801-4116-9105-80a91cf15c1b',
#   'target': 'attack-pattern--e01be9c5-e763-4caf-aeb7-000b416aef67'},
#  {'source': 'x-mitre-data-component--a7f22107-02e5-4982-9067-6625d4a1765a',
#   'target': 'attack-pattern--0bda01d5-4c1d-4062-8ee2-6872334383c3'},
#  {'source': 'intrusion-set--8c1f0187-0826-4320-bddc-5f326cfcfe2c',
#   'target': 'attack-pattern--e64c62cf-9cd7-4a14-94ec-cdaac43ab44b'},
#  {'source': 'campaign--aa73efef-1418-4dbe-b43c-87a498e97234',
#   'target': 'attack-pattern--208884f1-7b83-4473-ac22-4e1cf6c41471'},
#  {'source': 'malware--47afe41c-4c08-485e-b062-c3bd209a1cce',
#   'target': 'attack-pattern--24bfaeba-cb0d-4525-b3dc-507c77ecec41'},
#  {'source': 'malware--3249e92a-870b-426d-8790-ba311c1abfb4',
#   'target': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0'},
#  {'source': 'course-of-action--2a4f6c11-a4a7-4cb9-b0ef-6ae1bb3a718a',
#   'target': 'attack-pattern--c9e0c59e-162e-40a4-b8b1-78fab4329ada'},
#  {'source': 'x-mitre-data-component--5297a638-1382-4f0c-8472-0d21830bf705',
#   'target': 'attack-pattern--106c0cf6-bf73-4601-9aa8-0945c2715ec5'},
#  {'source': 'malware--d23de441-f9cf-4802-b1ff-f588a11a896b',
#   'target': 'attack-pattern--c3d4bdd9-2cfe-4a80-9d0c-07a29ecdce8f'},
#  {'source': 'attack-pattern--04ee0cb7-dac3-4c6c-9387-4c6aa096f4cf',
#   'target': 'attack-pattern--cbb66055-0325-4111-aca0-40547b6ad5b0'},
#  {'source': 'tool--999c4e6e-b8dc-4b4f-8d6e-1b829f29997e',
#   'target': 'attack-pattern--b4694861-542c-48ea-9eb1-10d356e7140a'},
#  {'source': 'malware--c8b6cc43-ce61-42ae-87f3-a5f10526f952',
#   'target': 'attack-pattern--d1fcf083-a721-4223-aedf-bf8960798d62'},
#  {'source': 'malware--958b5d06-8bb0-4c5b-a2e7-0130fe654ac7',
#   'target': 'attack-pattern--dfd7cc1d-e1d8-4394-a198-97c4cab8aa67'},
#  {'source': 'malware--af2ad3b7-ab6a-4807-91fd-51bcaff9acbb',
#   'target': 'attack-pattern--7bc57495-ea59-4380-be31-a64af124ef18'},
#  {'source': 'intrusion-set--b7f627e2-0817-4cd5-8d50-e75f8aa85cc6',
#   'target': 'attack-pattern--bf1b6176-597c-4600-bfcd-ac989670f96b'},
#  {'source': 'campaign--b03d5112-e23a-4ac8-add0-be7502d24eff',
#   'target': 'tool--4664b683-f578-434f-919b-1c1aad2a1111'},
#  {'source': 'intrusion-set--467271fd-47c0-4e90-a3f9-d84f5cf790d0',
#   'target': 'attack-pattern--3ee16395-03f0-4690-a32e-69ce9ada0f9e'},
#  {'source': 'malware--92b03a94-7147-4952-9d5a-b4d24da7487c',
#   'target': 'attack-pattern--7bc57495-ea59-4380-be31-a64af124ef18'},
#  {'source': 'intrusion-set--17862c7d-9e60-48a0-b48e-da4dc4c3f6b0',
#   'target': 'attack-pattern--53ac20cd-aca3-406e-9aa0-9fc7fdc60a5a'},
#  {'source': 'course-of-action--cc2399fd-3cd3-4319-8d0a-fbd6420cdaf8',
#   'target': 'attack-pattern--cc3502b5-30cc-4473-ad48-42d51a6ef6d1'},
#  {'source': 'malware--df9b350b-d4f9-4e79-a826-75cc75fbc1eb',
#   'target': 'attack-pattern--3ccef7ae-cb5e-48f6-8302-897105fbf55c'},
#  {'source': 'tool--c8655260-9f4b-44e3-85e1-6538a5f6e4f4',
#   'target': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0'},
#  {'source': 'malware--b6b3dfc7-9a81-43ff-ac04-698bad48973a',
#   'target': 'attack-pattern--d1fcf083-a721-4223-aedf-bf8960798d62'},
#  {'source': 'malware--a0ab8a96-40c9-4483-8a54-3fafa6d6007a',
#   'target': 'attack-pattern--74d2a63f-3c7b-4852-92da-02d8fbab16da'},
#  {'source': 'intrusion-set--b7f627e2-0817-4cd5-8d50-e75f8aa85cc6',
#   'target': 'attack-pattern--2b742742-28c3-4e1b-bab7-8350d6300fa7'},
#  {'source': 'intrusion-set--7f848c02-4d1e-4808-a4ae-4670681370a9',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'malware--dc5d1a33-62aa-4a0c-aa8c-589b87beb11e',
#   'target': 'attack-pattern--df8b2a25-8bdf-4856-953c-a04372b1c161'},
#  {'source': 'malware--c46eb8e6-bf29-4696-8008-3ddb0b4ca470',
#   'target': 'attack-pattern--853c4192-4311-43e1-bfbb-b11b14911852'},
#  {'source': 'malware--4efc3e00-72f2-466a-ab7c-8a7dc6603b19',
#   'target': 'attack-pattern--0d91b3c0-5e50-47c3-949a-2a796f04d144'},
#  {'source': 'tool--3433a9e8-1c47-4320-b9bf-ed449061d1c3',
#   'target': 'attack-pattern--6faf650d-bf31-4eb4-802d-1000cf38efaf'},
#  {'source': 'malware--99854cc8-f202-4e03-aa0a-4f8a4af93229',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'course-of-action--eb88d97c-32f1-40be-80f0-d61a4b0b4b31',
#   'target': 'attack-pattern--01327cde-66c4-4123-bf34-5f258d59457b'},
#  {'source': 'intrusion-set--c416b28c-103b-4df1-909e-78089a7e0e5f',
#   'target': 'attack-pattern--d742a578-d70e-4d0e-96a6-02a9c30204e6'},
#  {'source': 'malware--4327aff5-f194-440c-b499-4d9730cc1eab',
#   'target': 'attack-pattern--3ccef7ae-cb5e-48f6-8302-897105fbf55c'},
#  {'source': 'malware--1d1fce2f-0db5-402b-9843-4278a0694637',
#   'target': 'attack-pattern--b0533c6e-8fea-4788-874f-b799cacc4b92'},
#  {'source': 'malware--edc5e045-5401-42bb-ad92-52b5b2ee0de9',
#   'target': 'attack-pattern--b97f1d35-4249-4486-a6b5-ee60ccf24fab'},
#  {'source': 'malware--49fee0b0-390e-4bde-97f8-97ed46bd19b7',
#   'target': 'attack-pattern--1b7b1806-7746-41a1-a35d-e48dae25ddba'},
#  {'source': 'intrusion-set--381fcf73-60f6-4ab2-9991-6af3cbc35192',
#   'target': 'attack-pattern--3257eb21-f9a7-4430-8de1-d8b6e288f529'},
#  {'source': 'malware--327b3a25-9e60-4431-b3b6-93b9c64eacbc',
#   'target': 'attack-pattern--7bd9c723-2f78-4309-82c5-47cad406572b'},
#  {'source': 'intrusion-set--222fbd21-fc4f-4b7e-9f85-0e6e3a76c33f',
#   'target': 'attack-pattern--e358d692-23c0-4a31-9eb6-ecc13a8d7735'},
#  {'source': 'x-mitre-data-component--a7f22107-02e5-4982-9067-6625d4a1765a',
#   'target': 'attack-pattern--613d08bc-e8f4-4791-80b0-c8b974340dfd'},
#  {'source': 'x-mitre-data-component--639e87f3-acb6-448a-9645-258f20da4bc5',
#   'target': 'attack-pattern--22905430-4901-4c2a-84f6-98243cb173f8'},
#  {'source': 'malware--cc5497f7-a9e8-436f-94da-b2b4a9b9ad3c',
#   'target': 'attack-pattern--92d7da27-2d91-488e-a00c-059dc162766d'},
#  {'source': 'intrusion-set--56319646-eb6e-41fc-ae53-aadfa7adb924',
#   'target': 'attack-pattern--2959d63f-73fd-46a1-abd2-109d7dcede32'},
#  {'source': 'malware--c2417bab-3189-4d4d-9d60-96de2cdaf0ab',
#   'target': 'attack-pattern--2aed01ad-3df3-4410-a8cb-11ea4ded587c'},
#  {'source': 'campaign--aa73efef-1418-4dbe-b43c-87a498e97234',
#   'target': 'attack-pattern--970a3432-3237-47ad-bcca-7d8cbb217736'},
#  {'source': 'malware--1d1fce2f-0db5-402b-9843-4278a0694637',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--ec9e00dd-0313-4d5b-8105-c20aa47abffc',
#   'target': 'attack-pattern--03d7999c-1f4c-42cc-8373-e7690d318104'},
#  {'source': 'intrusion-set--0d4ac089-ced4-4cc4-a989-174d08e6d030',
#   'target': 'attack-pattern--155207c0-7f53-4f13-a06b-0a9907ef5096'},
#  {'source': 'intrusion-set--222fbd21-fc4f-4b7e-9f85-0e6e3a76c33f',
#   'target': 'attack-pattern--01a5a209-b94c-450b-b7f9-946497d91055'},
#  {'source': 'x-mitre-data-component--2b3bfe19-d59a-460d-93bb-2f546adc2d2c',
#   'target': 'attack-pattern--0c2d00da-7742-49e7-9928-4514e5075d32'},
#  {'source': 'malware--ba09b86c-1c40-4ff1-bda0-0d8c4ca35997',
#   'target': 'attack-pattern--3489cfc5-640f-4bb3-a103-9137b97de79f'},
#  {'source': 'x-mitre-data-component--1067aa74-5796-4d9b-b4f1-a4c9eb6fd9da',
#   'target': 'attack-pattern--eb897572-8979-4242-a089-56f294f4c91d'},
#  {'source': 'malware--e7a5229f-05eb-440e-b982-9a6d2b2b87c8',
#   'target': 'attack-pattern--43e7dc91-05b2-474c-b9ac-2ed4fe101f4d'},
#  {'source': 'malware--f25aab1a-0cef-4910-a85d-bb38b32ea41a',
#   'target': 'attack-pattern--d63a3fb8-9452-4e9d-a60a-54be68d5998c'},
#  {'source': 'intrusion-set--f9d6633a-55e6-4adc-9263-6ae080421a13',
#   'target': 'attack-pattern--40597f16-0963-4249-bf4c-ac93b7fb9807'},
#  {'source': 'campaign--46421788-b6e1-4256-b351-f8beffd1afba',
#   'target': 'attack-pattern--2e34237d-8574-43f6-aace-ae2915de8597'},
#  {'source': 'malware--3c18ad16-9eaf-4649-984e-68551bff0d47',
#   'target': 'attack-pattern--03d7999c-1f4c-42cc-8373-e7690d318104'},
#  {'source': 'malware--56e6b6c2-e573-4969-8bab-783205cebbbf',
#   'target': 'attack-pattern--d63a3fb8-9452-4e9d-a60a-54be68d5998c'},
#  {'source': 'campaign--519ee082-8ab6-439b-988f-a8a3f02c8d30',
#   'target': 'tool--11f8d7eb-1927-4806-9267-3a11d4d4d6be'},
#  {'source': 'malware--7343e208-7cab-45f2-a47b-41ba5e2f0fab',
#   'target': 'attack-pattern--837f9164-50af-4ac0-8219-379d8a74cefc'},
#  {'source': 'malware--750eb92a-7fdf-451e-9592-1d42357018f1',
#   'target': 'attack-pattern--df8b2a25-8bdf-4856-953c-a04372b1c161'},
#  {'source': 'intrusion-set--467271fd-47c0-4e90-a3f9-d84f5cf790d0',
#   'target': 'malware--4327aff5-f194-440c-b499-4d9730cc1eab'},
#  {'source': 'x-mitre-data-component--c0a4a086-cc20-4e1e-b7cb-29d99dfa3fb1',
#   'target': 'attack-pattern--acd0ba37-7ba9-4cc5-ac61-796586cd856d'},
#  {'source': 'intrusion-set--fe8796a4-2a02-41a0-9d27-7aa1e995feb6',
#   'target': 'attack-pattern--9efb1ea7-c37b-4595-9640-b7680cd84279'},
#  {'source': 'malware--805480f1-6caa-4a67-8ca9-b2b39650d986',
#   'target': 'attack-pattern--3ccef7ae-cb5e-48f6-8302-897105fbf55c'},
#  {'source': 'malware--b00f90b6-c75c-4bfd-b813-ca9e6c9ebf29',
#   'target': 'attack-pattern--c21d5a77-d422-4a69-acd7-2c53c1faa34b'},
#  {'source': 'intrusion-set--4c4a7846-45d5-4761-8eea-725fa989914c',
#   'target': 'attack-pattern--4f9ca633-15c5-463c-9724-bdcd54fde541'},
#  {'source': 'campaign--4603cf2f-06d0-4970-9c5d-5071b08c817f',
#   'target': 'malware--0db09158-6e48-4e7c-8ce7-2b10b9c0c039'},
#  {'source': 'intrusion-set--899ce53f-13a0-479b-a0e4-67d46e241542',
#   'target': 'malware--959f3b19-2dc8-48d5-8942-c66813a5101a'},
#  {'source': 'malware--77e0ecf7-ca91-4c06-8012-8e728986a87a',
#   'target': 'attack-pattern--365be77f-fc0e-42ee-bac8-4faf806d9336'},
#  {'source': 'x-mitre-data-component--181a9f8c-c780-4f1f-91a8-edb770e904ba',
#   'target': 'attack-pattern--ee7ff928-801c-4f34-8a99-3df965e581a5'},
#  {'source': 'malware--5a3a31fe-5a8f-48e1-bff0-a753e5b1be70',
#   'target': 'attack-pattern--09c4c11e-4fa1-4f8c-8dad-3cf8e69ad119'},
#  {'source': 'malware--5f9f7648-04ba-4a9f-bb4c-2a13e74572bd',
#   'target': 'attack-pattern--0259baeb-9f63-4c69-bf10-eb038c390688'},
#  {'source': 'course-of-action--9bb9e696-bff8-4ae1-9454-961fc7d91d5f',
#   'target': 'attack-pattern--cfb525cc-5494-401d-a82b-2539ca46a561'},
#  {'source': 'campaign--b03d5112-e23a-4ac8-add0-be7502d24eff',
#   'target': 'tool--066b057c-944e-4cfc-b654-e3dfba04b926'},
#  {'source': 'malware--edc5e045-5401-42bb-ad92-52b5b2ee0de9',
#   'target': 'attack-pattern--ec8fc7e2-b356-455c-8db5-2e37be158e7d'},
#  {'source': 'campaign--0257b35b-93ef-4a70-80dd-ad5258e6045b',
#   'target': 'attack-pattern--c1b68a96-3c48-49ea-a6c0-9b27359f9c19'},
#  {'source': 'course-of-action--cc2399fd-3cd3-4319-8d0a-fbd6420cdaf8',
#   'target': 'attack-pattern--767dbf9e-df3f-45cb-8998-4903ab5f80c0'},
#  {'source': 'malware--cad3ba95-8c89-4146-ab10-08daa813f9de',
#   'target': 'attack-pattern--cba37adb-d6fb-4610-b069-dd04c0643384'},
#  {'source': 'malware--bfd2738c-8b43-43c3-bc9f-d523c8e88bf4',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'tool--3433a9e8-1c47-4320-b9bf-ed449061d1c3',
#   'target': 'attack-pattern--68a0c5ed-bee2-4513-830d-5b0d650139bd'},
#  {'source': 'x-mitre-data-component--2b3bfe19-d59a-460d-93bb-2f546adc2d2c',
#   'target': 'attack-pattern--ef67e13e-5598-4adc-bdb2-998225874fa9'},
#  {'source': 'malware--e8545794-b98c-492b-a5b3-4b5a02682e37',
#   'target': 'attack-pattern--2f6b4ed7-fef1-44ba-bcb8-1b4beb610b64'},
#  {'source': 'malware--bfd2738c-8b43-43c3-bc9f-d523c8e88bf4',
#   'target': 'attack-pattern--132d5b37-aac5-4378-a8dc-3127b18a73dc'},
#  {'source': 'malware--54a73038-1937-4d71-a253-316e76d5413c',
#   'target': 'attack-pattern--cd25c1b4-935c-4f0e-ba8d-552f28bc4783'},
#  {'source': 'attack-pattern--4ab929c6-ee2d-4fb5-aab4-b14be2ed7179',
#   'target': 'attack-pattern--1ecb2399-e8ba-4f6b-8ba7-5c27d49405cf'},
#  {'source': 'intrusion-set--df71bb3b-813c-45eb-a8bc-f2a419837411',
#   'target': 'malware--8a59f456-79a0-4151-9f56-9b1a67332af2'},
#  {'source': 'x-mitre-data-component--84572de3-9583-4c73-aabd-06ea88123dd8',
#   'target': 'attack-pattern--2fee9321-3e71-4cf4-af24-d4d40d355b34'},
#  {'source': 'malware--80a014ba-3fef-4768-990b-37d8bd10d7f4',
#   'target': 'attack-pattern--bf176076-b789-408e-8cba-7275e81c0ada'},
#  {'source': 'malware--454fe82d-6fd2-4ac6-91ab-28a33fe01369',
#   'target': 'attack-pattern--215d9700-5881-48b8-8265-6449dbb7195d'},
#  {'source': 'malware--3553b49d-d4ae-4fb6-ab17-0adbc520c888',
#   'target': 'attack-pattern--4933e63b-9b77-476e-ab29-761bc5b7d15a'},
#  {'source': 'intrusion-set--894aab42-3371-47b1-8859-a4a074c804c8',
#   'target': 'attack-pattern--d336b553-5da9-46ca-98a8-0b23f49fb447'},
#  {'source': 'malware--b2c5d3ca-b43a-4888-ad8d-e2d43497bf85',
#   'target': 'attack-pattern--f7c0689c-4dbd-489b-81be-7cb7c7079ade'},
#  {'source': 'x-mitre-data-component--ed0dd8aa-1677-4551-bb7d-8da767617e1b',
#   'target': 'attack-pattern--435dfb86-2697-4867-85b5-2fef496c0517'},
#  {'source': 'x-mitre-data-component--685f917a-e95e-4ba0-ade1-c7d354dae6e0',
#   'target': 'attack-pattern--58a3e6aa-4453-4cc8-a51f-4befe80b31a8'},
#  {'source': 'intrusion-set--813636db-3939-4a45-bea9-6113e970c029',
#   'target': 'attack-pattern--d40239b3-05ff-46d8-9bdd-b46d13463ef9'},
#  {'source': 'malware--edb24a93-1f7a-4bbf-a738-1397a14662c6',
#   'target': 'attack-pattern--f3c544dc-673c-4ef3-accb-53229f1ae077'},
#  {'source': 'malware--8b880b41-5139-4807-baa9-309690218719',
#   'target': 'attack-pattern--a3e1e6c5-9c74-4fc0-a16c-a9d228c17829'},
#  {'source': 'malware--e6ef745b-077f-42e1-a37d-29eecff9c754',
#   'target': 'attack-pattern--d1fcf083-a721-4223-aedf-bf8960798d62'},
#  {'source': 'campaign--df74f7ad-b10d-431c-9f1d-a2bc18dadefa',
#   'target': 'attack-pattern--3f886f2a-874f-4333-b794-aa6075009b1c'},
#  {'source': 'x-mitre-data-component--3772e279-27d6-477a-9fe3-c6beb363594c',
#   'target': 'attack-pattern--0a3ead4e-6d47-4ccb-854c-a6a4f9d96b22'},
#  {'source': 'malware--0998045d-f96e-4284-95ce-3c8219707486',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'malware--c113230f-f044-423b-af63-9b63c802f5ae',
#   'target': 'attack-pattern--d1fcf083-a721-4223-aedf-bf8960798d62'},
#  {'source': 'course-of-action--b045d015-6bed-4490-bd38-56b41ece59a0',
#   'target': 'attack-pattern--8a2f40cf-8325-47f9-96e4-b1ca4c7389bd'},
#  {'source': 'tool--1b3b8f96-43b1-4460-8e02-1f53d7802fb9',
#   'target': 'attack-pattern--e848506b-8484-4410-8017-3d235a52f5b3'},
#  {'source': 'malware--c009560a-f097-45a3-8f9f-78ec1440a783',
#   'target': 'attack-pattern--1996eef1-ced3-4d7f-bf94-33298cabbf72'},
#  {'source': 'intrusion-set--4a2ce82e-1a74-468a-a6fb-bbead541383c',
#   'target': 'attack-pattern--9efb1ea7-c37b-4595-9640-b7680cd84279'},
#  {'source': 'attack-pattern--1644e709-12d2-41e5-a60f-3470991f5011',
#   'target': 'attack-pattern--0a3ead4e-6d47-4ccb-854c-a6a4f9d96b22'},
#  {'source': 'campaign--df74f7ad-b10d-431c-9f1d-a2bc18dadefa',
#   'target': 'attack-pattern--8f104855-e5b7-4077-b1f5-bc3103b41abe'},
#  {'source': 'malware--e9e9bfe2-76f4-4870-a2a1-b7af89808613',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'intrusion-set--d519164e-f5fa-4b8c-a1fb-cf0172ad0983',
#   'target': 'attack-pattern--4f9ca633-15c5-463c-9724-bdcd54fde541'},
#  {'source': 'malware--0c52f5bc-557d-4083-bd27-66d7cdb794bb',
#   'target': 'attack-pattern--d511a6f6-4a33-41d5-bc95-c343875d1377'},
#  {'source': 'x-mitre-data-component--ff93f688-d7a4-49cf-9c79-a14454da8428',
#   'target': 'attack-pattern--94cb00a4-b295-4d06-aa2b-5653b9c1be9c'},
#  {'source': 'intrusion-set--381fcf73-60f6-4ab2-9991-6af3cbc35192',
#   'target': 'attack-pattern--d511a6f6-4a33-41d5-bc95-c343875d1377'},
# ...
#  {'source': 'x-mitre-data-component--685f917a-e95e-4ba0-ade1-c7d354dae6e0',
#   'target': 'attack-pattern--808e6329-ca91-4b87-ac2d-8eadc5f8f327'},
#  {'source': 'malware--54a73038-1937-4d71-a253-316e76d5413c',
#   'target': 'attack-pattern--7e150503-88e7-4861-866b-ff1ac82c4475'},
#  {'source': 'malware--876f6a77-fbc5-4e13-ab1a-5611986730a3',
#   'target': 'attack-pattern--f3c544dc-673c-4ef3-accb-53229f1ae077'},
#  {'source': 'attack-pattern--b2d03cea-aec1-45ca-9744-9ee583c1e1cc',
#   'target': 'attack-pattern--a93494bb-4b80-4ea1-8695-3236a49916fd'},
#  {'source': 'malware--fb575479-14ef-41e9-bfab-0b7cf10bec73',
#   'target': 'attack-pattern--09a60ea3-a8d1-4ae5-976e-5783248b72a4'},
#  {'source': 'intrusion-set--fd66436e-4d33-450e-ac4c-f7810f1c85f4',
#   'target': 'attack-pattern--4fe28b27-b13c-453e-a386-c2ef362a573b'},
#  {'source': 'tool--5256c0f8-9108-4c92-8b09-482dfacdcd94',
#   'target': 'attack-pattern--d63a3fb8-9452-4e9d-a60a-54be68d5998c'},
#  {'source': 'malware--d6e55656-e43f-411f-a7af-45df650471c5',
#   'target': 'attack-pattern--df8b2a25-8bdf-4856-953c-a04372b1c161'},
#  {'source': 'malware--37cc7eb6-12e3-467b-82e8-f20f2cc73c69',
#   'target': 'attack-pattern--24bfaeba-cb0d-4525-b3dc-507c77ecec41'},
#  {'source': 'x-mitre-data-component--b9d031bb-d150-4fc6-8025-688201bf3ffd',
#   'target': 'attack-pattern--791481f8-e96a-41be-b089-a088763083d4'},
#  {'source': 'malware--d9f7383c-95ec-4080-bbce-121c9384457b',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--b00f90b6-c75c-4bfd-b813-ca9e6c9ebf29',
#   'target': 'attack-pattern--09b130a2-a77e-4af0-a361-f46f9aad1345'},
#  {'source': 'intrusion-set--4a2ce82e-1a74-468a-a6fb-bbead541383c',
#   'target': 'attack-pattern--cc3502b5-30cc-4473-ad48-42d51a6ef6d1'},
#  {'source': 'intrusion-set--62a64fd3-aaf7-4d09-a375-d6f8bb118481',
#   'target': 'malware--88c621a7-aef9-4ae0-94e3-1fc87123eb24'},
#  {'source': 'malware--8ae43c46-57ef-47d5-a77a-eebb35628db2',
#   'target': 'attack-pattern--f24faf46-3b26-4dbb-98f2-63460498e433'},
#  {'source': 'malware--7f4bbe05-1674-4087-8a16-8f1ad61b6152',
#   'target': 'attack-pattern--47f2d673-ca62-47e9-929b-1b0be9657611'},
#  {'source': 'malware--54cc1d4f-5c53-4f0e-9ef5-11b4998e82e4',
#   'target': 'attack-pattern--58a3e6aa-4453-4cc8-a51f-4befe80b31a8'},
#  {'source': 'malware--f8dfbc54-b070-4224-b560-79aaa5f835bd',
#   'target': 'attack-pattern--58a3e6aa-4453-4cc8-a51f-4befe80b31a8'},
#  {'source': 'intrusion-set--6713ab67-e25b-49cc-808d-2b36d4fbc35c',
#   'target': 'tool--b77b563c-34bb-4fb8-86a3-3694338f7b47'},
#  {'source': 'malware--44c75271-0e4d-496f-ae0a-a6d883a42a65',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'course-of-action--21da4fd4-27ad-4e9c-b93d-0b9b14d02c96',
#   'target': 'attack-pattern--be055942-6e63-49d7-9fa1-9cb7d8a8f3f4'},
#  {'source': 'course-of-action--78bb71be-92b4-46de-acd6-5f998fedf1cc',
#   'target': 'attack-pattern--19401639-28d0-4c3c-adcc-bc2ba22f6421'},
#  {'source': 'intrusion-set--894aab42-3371-47b1-8859-a4a074c804c8',
#   'target': 'attack-pattern--7385dfaf-6886-4229-9ecd-6fd678040830'},
#  {'source': 'campaign--93c23946-49af-41f4-ac03-40f9ffc7419b',
#   'target': 'attack-pattern--e358d692-23c0-4a31-9eb6-ecc13a8d7735'},
#  {'source': 'intrusion-set--7eda3dd8-b09b-4705-8090-c2ad9fb8c14d',
#   'target': 'malware--cad3ba95-8c89-4146-ab10-08daa813f9de'},
#  {'source': 'malware--a04d9a4c-bb52-40bf-98ec-e350c2d6a862',
#   'target': 'attack-pattern--b8902400-e6c5-4ba2-95aa-2d35b442b118'},
#  {'source': 'campaign--b03d5112-e23a-4ac8-add0-be7502d24eff',
#   'target': 'attack-pattern--e358d692-23c0-4a31-9eb6-ecc13a8d7735'},
#  {'source': 'malware--efece7e8-e40b-49c2-9f84-c55c5c93d05c',
#   'target': 'attack-pattern--4eeaf8a9-c86b-4954-a663-9555fb406466'},
#  {'source': 'intrusion-set--247cb30b-955f-42eb-97a5-a89fef69341e',
#   'target': 'attack-pattern--42e8de7b-37b2-4258-905a-6897815e58e0'},
#  {'source': 'campaign--7854c1a0-f06c-4876-98a4-4bbd34751b05',
#   'target': 'attack-pattern--be055942-6e63-49d7-9fa1-9cb7d8a8f3f4'},
#  {'source': 'malware--6f6b2353-4b39-40ce-9d6d-d00b7a61e656',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'intrusion-set--222fbd21-fc4f-4b7e-9f85-0e6e3a76c33f',
#   'target': 'attack-pattern--e3a12395-188d-4051-9a16-ea8e14d07b88'},
#  {'source': 'malware--1492d0f8-7e14-4af3-9239-bc3fe10d3407',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'course-of-action--feff9142-e8c2-46f4-842b-bd6fb3d41157',
#   'target': 'attack-pattern--035bb001-ab69-4a0b-9f6c-2de8b09e1b9d'},
#  {'source': 'malware--326af1cd-78e7-45b7-a326-125d2f7ef8f2',
#   'target': 'attack-pattern--7bc57495-ea59-4380-be31-a64af124ef18'},
#  {'source': 'malware--bbcd7a02-ef24-4171-ac94-a93540173b94',
#   'target': 'attack-pattern--3fc9b85a-2862-4363-a64d-d692e3ffbee0'},
#  {'source': 'malware--4f6aa78c-c3d4-4883-9840-96ca2f5d6d47',
#   'target': 'attack-pattern--1996eef1-ced3-4d7f-bf94-33298cabbf72'},
#  {'source': 'malware--e7a5229f-05eb-440e-b982-9a6d2b2b87c8',
#   'target': 'attack-pattern--25659dd6-ea12-45c4-97e6-381e3e4b593e'},
#  {'source': 'intrusion-set--d8bc9788-4f7d-41a9-9e9d-ee1ea18a8cf7',
#   'target': 'attack-pattern--7ad38ef1-381a-406d-872a-38b136eb5ecc'},
#  {'source': 'malware--432555de-63bf-4f2a-a3fa-f720a4561078',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--64fa0de0-6240-41f4-8638-f4ca7ed528fd',
#   'target': 'attack-pattern--7bdca9d5-d500-4d7d-8c52-5fd47baf4c0c'},
#  {'source': 'intrusion-set--c1aab4c9-4c34-4f4f-8541-d529e46a07f9',
#   'target': 'tool--2e45723a-31da-4a7e-aaa6-e01998a6788f'},
#  {'source': 'malware--4e6464d2-69df-4e56-8d4c-1973f84d7b80',
#   'target': 'attack-pattern--3ccef7ae-cb5e-48f6-8302-897105fbf55c'},
#  {'source': 'x-mitre-data-component--9ce98c86-8d30-4043-ba54-0784d478d0b5',
#   'target': 'attack-pattern--1f9c2bae-b441-4f66-a8af-b65946ee72f2'},
#  {'source': 'intrusion-set--df71bb3b-813c-45eb-a8bc-f2a419837411',
#   'target': 'attack-pattern--365be77f-fc0e-42ee-bac8-4faf806d9336'},
#  {'source': 'malware--00c3bfcb-99bd-4767-8c03-b08f585f5c8a',
#   'target': 'attack-pattern--707399d6-ab3e-4963-9315-d9d3818cd6a0'},
#  {'source': 'malware--04227b24-7817-4de1-9050-b7b1b57f5866',
#   'target': 'attack-pattern--7bc57495-ea59-4380-be31-a64af124ef18'},
#  {'source': 'x-mitre-data-component--16e07530-764b-4d83-bae0-cdbfc31bf21d',
#   'target': 'attack-pattern--d45a3d09-b3cf-48f4-9f0f-f521ee5cb05c'},
#  {'source': 'campaign--7ec2826c-0bf0-4b47-acae-fd683431a4ca',
#   'target': 'attack-pattern--a2fdce72-04b2-409a-ac10-cc1695f4fce0'},
#  {'source': 'intrusion-set--7eda3dd8-b09b-4705-8090-c2ad9fb8c14d',
#   'target': 'attack-pattern--40f5caa0-4cb7-4117-89fc-d421bb493df3'},
#  {'source': 'intrusion-set--c93fccb1-e8e8-42cf-ae33-2ad1d183913a',
#   'target': 'attack-pattern--e196b5c5-8118-4a1c-ab8a-936586ce3db5'},
#  {'source': 'malware--cb741463-f0fe-42e0-8d45-bc7e8335f5ae',
#   'target': 'attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df007ca70a'},
#  {'source': 'malware--8d9e758b-735f-4cbc-ba7c-32cd15138b2a',
#   'target': 'attack-pattern--57340c81-c025-4189-8fa0-fc7ede51bae4'},
#  {'source': 'intrusion-set--df71bb3b-813c-45eb-a8bc-f2a419837411',
#   'target': 'malware--03ea629c-517a-41e3-94f8-c7e5368cf8f4'},
#  {'source': 'intrusion-set--44e43fad-ffcb-4210-abcf-eaaed9735f80',
#   'target': 'attack-pattern--09a60ea3-a8d1-4ae5-976e-5783248b72a4'},
#  {'source': 'x-mitre-data-component--685f917a-e95e-4ba0-ade1-c7d354dae6e0',
#   'target': 'attack-pattern--28abec6c-4443-4b03-8206-07f2e264a6b4'},
#  {'source': 'malware--a60657fa-e2e7-4f8f-8128-a882534ae8c5',
#   'target': 'attack-pattern--5d0d3609-d06d-49e1-b9c9-b544e0c618cb'},
#  {'source': 'malware--2fb26586-2b53-4b9a-ad4f-2b3bcb9a2421',
#   'target': 'attack-pattern--03d7999c-1f4c-42cc-8373-e7690d318104'},
#  {'source': 'course-of-action--93e7968a-9074-4eac-8ae9-9f5200ec3317',
#   'target': 'attack-pattern--92a78814-b191-47ca-909c-1ccfe3777414'},
#  {'source': 'malware--8f423bd7-6ca7-4303-9e85-008c7ad5fdaa',
#   'target': 'attack-pattern--4ae4f953-fe58-4cc8-a327-33257e30a830'},
#  {'source': 'malware--ec9e00dd-0313-4d5b-8105-c20aa47abffc',
#   'target': 'attack-pattern--799ace7f-e227-4411-baa0-8868704f2a69'},
#  {'source': 'intrusion-set--899ce53f-13a0-479b-a0e4-67d46e241542',
#   'target': 'tool--65370d0b-3bd4-4653-8cf9-daf56f6be830'},
#  {'source': 'malware--e2d34c63-6f5a-41f5-86a2-e2380f27f858',
#   'target': 'attack-pattern--da051493-ae9c-4b1b-9760-c009c46c9b56'},
#  {'source': 'intrusion-set--4283ae19-69c7-4347-a35e-b56f08eb660b',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--f72251cb-2be5-421f-a081-99c29a1209e7',
#   'target': 'attack-pattern--a782ebe2-daba-42c7-bc82-e8e9d923162d'},
#  {'source': 'malware--e066bf86-9cfb-407a-9d25-26fd5d91e360',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'malware--75ecdbf1-c2bb-4afc-a3f9-c8da4de8c661',
#   'target': 'attack-pattern--9db0cf3a-a3c9-4012-8268-123b9db6fd82'},
#  {'source': 'intrusion-set--2a7914cf-dff3-428d-ab0f-1014d1c28aeb',
#   'target': 'attack-pattern--2e34237d-8574-43f6-aace-ae2915de8597'},
#  {'source': 'malware--925a6c52-5cf0-4fec-99de-b0d6917d8593',
#   'target': 'attack-pattern--348f1eef-964b-4eb6-bb53-69b3dcb0c643'},
#  {'source': 'x-mitre-data-component--685f917a-e95e-4ba0-ade1-c7d354dae6e0',
#   'target': 'attack-pattern--98034fef-d9fb-4667-8dc4-2eab6231724c'},
#  {'source': 'x-mitre-data-component--84572de3-9583-4c73-aabd-06ea88123dd8',
#   'target': 'attack-pattern--fa44a152-ac48-441e-a524-dd7b04b8adcd'},
#  {'source': 'malware--08d20cd2-f084-45ee-8558-fa6ef5a18519',
#   'target': 'attack-pattern--f7c0689c-4dbd-489b-81be-7cb7c7079ade'},
#  {'source': 'malware--a0ab8a96-40c9-4483-8a54-3fafa6d6007a',
#   'target': 'attack-pattern--005a06c6-14bf-4118-afa0-ebcd8aebb0c9'},
#  {'source': 'intrusion-set--0ec2f388-bf0f-4b5c-97b1-fc736d26c25f',
#   'target': 'attack-pattern--232b7f21-adf9-4b42-b936-b9d6f7df856e'},
#  {'source': 'x-mitre-data-component--3d20385b-24ef-40e1-9f56-f39750379077',
#   'target': 'attack-pattern--09b130a2-a77e-4af0-a361-f46f9aad1345'},
#  {'source': 'malware--cad3ba95-8c89-4146-ab10-08daa813f9de',
#   'target': 'attack-pattern--3ccef7ae-cb5e-48f6-8302-897105fbf55c'},
#  {'source': 'malware--20945359-3b39-4542-85ef-08ecb4e1c174',
#   'target': 'attack-pattern--774a3188-6ba9-4dc4-879d-d54ee48a5ce9'},
#  {'source': 'attack-pattern--02fefddc-fb1b-423f-a76b-7552dd211d4d',
#   'target': 'attack-pattern--1b7b1806-7746-41a1-a35d-e48dae25ddba'},
#  {'source': 'tool--4b57c098-f043-4da2-83ef-7588a6d426bc',
#   'target': 'attack-pattern--837f9164-50af-4ac0-8219-379d8a74cefc'},
#  {'source': 'intrusion-set--46bb06cb-f2d9-4b37-8c92-a27e224ad90d',
#   'target': 'attack-pattern--0c4b4fda-9062-47da-98b9-ceae2dcf052a'},
#  {'source': 'intrusion-set--44e43fad-ffcb-4210-abcf-eaaed9735f80',
#   'target': 'attack-pattern--3c4a2599-71ee-4405-ba1e-0e28414b4bc5'},
#  {'source': 'course-of-action--90f39ee1-d5a3-4aaa-9f28-3b42815b0d46',
#   'target': 'attack-pattern--806a49c4-970d-43f9-9acc-ac0ee11e6662'},
#  {'source': 'malware--9ea525fa-b0a9-4dde-84f2-bcea0137b3c1',
#   'target': 'attack-pattern--09a60ea3-a8d1-4ae5-976e-5783248b72a4'},
#  {'source': 'malware--0c824410-58ff-49b2-9cf2-1c96b182bdf0',
#   'target': 'attack-pattern--837f9164-50af-4ac0-8219-379d8a74cefc'},
#  {'source': 'malware--7bec698a-7e20-4fd3-bb6a-12787770fb1a',
#   'target': 'attack-pattern--24bfaeba-cb0d-4525-b3dc-507c77ecec41'},
#  {'source': 'course-of-action--cc2399fd-3cd3-4319-8d0a-fbd6420cdaf8',
#   'target': 'attack-pattern--389735f1-f21c-4208-b8f0-f8031e7169b8'},
#  {'source': 'intrusion-set--4ca1929c-7d64-4aab-b849-badbfc0c760d',
#   'target': 'tool--7fcbc4e8-1989-441f-9ac5-e7b6ff5806f1'},
#  {'source': 'intrusion-set--6a2e693f-24e5-451a-9f88-b36a108e5662',
#   'target': 'malware--b45747dc-87ca-4597-a245-7e16a61bc491'},
#  {'source': 'x-mitre-data-component--a953ca55-921a-44f7-9b8d-3d40141aa17e',
#   'target': 'attack-pattern--c3d4bdd9-2cfe-4a80-9d0c-07a29ecdce8f'},
#  {'source': 'x-mitre-data-component--61f1d40e-f3d0-4cc6-aa2d-937b6204194f',
#   'target': 'attack-pattern--20fb2507-d71c-455d-9b6d-6104461cf26b'},
#  {'source': 'malware--8d242fb4-9033-4f13-8a88-4b9b4bcd9a53',
#   'target': 'attack-pattern--354a7f88-63fb-41b5-a801-ce3b377b36f1'},
#  {'source': 'malware--36801ffb-5c85-4c50-9121-6122e389366d',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'intrusion-set--73a80fab-2aa3-48e0-a4d0-3a4828200aee',
#   'target': 'attack-pattern--ffeb0780-356e-4261-b036-cfb6bd234335'},
#  {'source': 'intrusion-set--cc613a49-9bfa-4e22-98d1-15ffbb03f034',
#   'target': 'attack-pattern--3ee16395-03f0-4690-a32e-69ce9ada0f9e'},
#  {'source': 'malware--94d6d788-07bb-4dcc-b62f-e02626b00108',
#   'target': 'attack-pattern--29be378d-262d-4e99-b00d-852d573628e6'},
#  {'source': 'intrusion-set--17862c7d-9e60-48a0-b48e-da4dc4c3f6b0',
#   'target': 'attack-pattern--7bc57495-ea59-4380-be31-a64af124ef18'},
#  {'source': 'malware--f4d8a2d6-c684-453a-8a14-cf4a94f755c5',
#   'target': 'attack-pattern--e6919abc-99f9-4c6c-95a5-14761e7b2add'},
#  {'source': 'campaign--712e38c3-a656-426a-9b3b-a6bfb63294c6',
#   'target': 'attack-pattern--045d0922-2310-4e60-b5e4-3302302cb3c5'},
#  {'source': 'malware--60a9c2f0-b7a5-4e8e-959c-e1a3ff314a5f',
#   'target': 'attack-pattern--1035cdf2-3e5f-446f-a7a7-e8f6d7925967'},
#  {'source': 'intrusion-set--bef4c620-0787-42a8-a96d-b7eb6e85917c',
#   'target': 'tool--f91162cc-1686-4ff8-8115-bf3f61a4cc7a'},
#  {'source': 'malware--edc5e045-5401-42bb-ad92-52b5b2ee0de9',
#   'target': 'attack-pattern--3c4a2599-71ee-4405-ba1e-0e28414b4bc5'},
#  {'source': 'malware--47afe41c-4c08-485e-b062-c3bd209a1cce',
#   'target': 'attack-pattern--f5d8eed6-48a9-4cdf-a3d7-d1ffa99c3d2a'},
#  {'source': 'intrusion-set--e44e0985-bc65-4a8f-b578-211c858128e3',
#   'target': 'malware--5864e59f-eb4c-43ad-83b2-b5e4fae056c9'},
#  {'source': 'intrusion-set--3753cc21-2dae-4dfb-8481-d004e74502cc',
#   'target': 'tool--afc079f3-c0ea-4096-b75d-3f05338b7f60'},
#  {'source': 'attack-pattern--76551c52-b111-4884-bc47-ff3e728f0156',
#   'target': 'attack-pattern--5282dd9a-d26d-4e16-88b7-7c0f4553daf4'},
#  {'source': 'intrusion-set--2a158b0a-7ef8-43cb-9985-bf34d1e12050',
#   'target': 'tool--cf23bf4a-e003-4116-bbae-1ea6c558d565'},
#  {'source': 'intrusion-set--32bca8ff-d900-4877-aa65-d70baa041b74',
#   'target': 'attack-pattern--d511a6f6-4a33-41d5-bc95-c343875d1377'},
#  {'source': 'tool--03342581-f790-4f03-ba41-e82e67392e23',
#   'target': 'attack-pattern--2aed01ad-3df3-4410-a8cb-11ea4ded587c'},
#  {'source': 'malware--326af1cd-78e7-45b7-a326-125d2f7ef8f2',
#   'target': 'attack-pattern--6faf650d-bf31-4eb4-802d-1000cf38efaf'},
#  {'source': 'intrusion-set--7a19ecb1-3c65-4de3-a230-993516aed6a6',
#   'target': 'attack-pattern--677569f9-a8b0-459e-ab24-7f18091fa7bf'},
#  {'source': 'campaign--4553292d-12c6-4a93-934d-12160370d4e0',
#   'target': 'malware--edf5aee2-9b1c-4252-8e64-25b12f14c8b3'},
#  {'source': 'attack-pattern--0533ab23-3f7d-463f-9bd8-634d27e4dee1',
#   'target': 'attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df007ca70a'},
#  {'source': 'intrusion-set--1c63d4ec-0a75-4daa-b1df-0d11af3d3cc1',
#   'target': 'attack-pattern--8c4aef43-48d5-49aa-b2af-c0cd58d30c3d'},
#  {'source': 'malware--e7a5229f-05eb-440e-b982-9a6d2b2b87c8',
#   'target': 'attack-pattern--9efb1ea7-c37b-4595-9640-b7680cd84279'},
#  {'source': 'intrusion-set--3fc023b2-c5cc-481d-9c3e-70141ae1a87e',
#   'target': 'attack-pattern--840a987a-99bd-4a80-a5c9-0cb2baa6cade'},
#  {'source': 'malware--e14085cb-0e8d-4be6-92ba-e3b93ee5978f',
#   'target': 'attack-pattern--e3b6daca-e963-4a69-aee6-ed4fd653ad58'},
#  {'source': 'malware--3161d76a-e2b2-4b97-9906-24909b735386',
#   'target': 'attack-pattern--8f4a33ec-8b1f-4b80-a2f6-642b2e479580'},
#  {'source': 'malware--47afe41c-4c08-485e-b062-c3bd209a1cce',
#   'target': 'attack-pattern--806a49c4-970d-43f9-9acc-ac0ee11e6662'},
#  {'source': 'malware--50d6688b-0985-4f3d-8cbe-0c796b30703b',
#   'target': 'attack-pattern--04fd5427-79c7-44ea-ae13-11b24778ff1c'},
#  {'source': 'course-of-action--7da0387c-ba92-4553-b291-b636ee42b2eb',
#   'target': 'attack-pattern--16ab6452-c3c1-497c-a47d-206018ca1ada'},
#  ...]

# %%
with open(data_dir+'attack_graph.json', 'w') as f:
    json.dump(graph, f)
